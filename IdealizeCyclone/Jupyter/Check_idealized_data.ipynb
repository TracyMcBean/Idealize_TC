# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#import plotly

# %%
# %matplotlib notebook

# %%
# Path of nc file to be read
file_path = '../../../../init_data/'
file_name = 'init_idealized_DOM01_2016081712.nc'
# Read in data
ds_ideal = xr.open_dataset(file_path+file_name)
#ds_ideal = xr.open_dataset('/scratch/usr/bekthkis/ICON_08_2019/Fiona2016/init_data/init_idealized_DOM01_2016081712.nc')

# data from run
ds_run = xr.open_dataset('../../../../out/idealized_1712_1812/FIONA_idealized-3D_DOM01_ML_0001.nc')

# %%
# Create plot of level (suitable for temperature plotting with the coolwarm colormap)
ax = plt.subplot(111)
plt.tripcolor(ds_ideal.clon, ds_ideal.clat, ds_ideal.temp.isel( time=0, height=60), cmap='coolwarm')
plt.title('Temperature in %s' % ds_ideal.z_ifc[60])
plt.xlabel('Longitude rad')  
plt.ylabel('Latitude rad')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

cbar = plt.colorbar() 
cbar.ax.set_ylabel('Temp in K')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Temp in K')

# %%
# Path of nc file to be read
file_path = '../../../../init_data/'
file_name = 'wind_idealized.nc'
# Read in data
ds = xr.open_dataset(file_path+file_name)

ds_orig = xr.open_dataset('../../../../init_data/dei4_NARVALII_2016081700_fg_DOM01_ML_0012.nc')

# %%
# Create plot of level (suitable for temperature plotting with the coolwarm colormap)
plt.figure(figsize=(9,7))
ax = plt.subplot(111)
plt.tripcolor(ds_ideal.clon, ds_ideal.clat, ds_ideal.vn.isel( time=0, height=60), cmap='PiYG')
plt.title('Wind')
plt.xlabel('Longitude rad')  
plt.ylabel('Latitude rad')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

cbar = plt.colorbar() 
cbar.ax.set_ylabel('Velocity m/s')
# Out:
# <div id='098881b8-2909-48cc-ba3c-1b6a6d0bd39d'></div>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b5f98bcbe55b> in <module>
#       2 plt.figure(figsize=(9,7))
#       3 ax = plt.subplot(111)
# ----> 4 plt.tripcolor(ds_ideal.clon, ds_ideal.clat, ds_ideal.vn.isel( time=0, height=60), cmap='PiYG')
#       5 plt.title('Wind')
#       6 plt.xlabel('Longitude rad')
#
# /sw/tools/python/anaconda3/2019.03/skl/lib/python3.7/site-packages/matplotlib/pyplot.py in tripcolor(*args, **kwargs)
#    3000 @_autogen_docstring(Axes.tripcolor)
#    3001 def tripcolor(*args, **kwargs):
# -> 3002     __ret = gca().tripcolor(*args, **kwargs)
#    3003     sci(__ret)
#    3004     return __ret
#
# /sw/tools/python/anaconda3/2019.03/skl/lib/python3.7/site-packages/matplotlib/axes/_axes.py in tripcolor(self, *args, **kwargs)
#    8105
# ...

# %%
# Create plot of level (suitable for temperature plotting with the coolwarm colormap)
plt.figure(figsize=(9,7))
ax = plt.subplot(111)
plt.tripcolor(ds_orig.clon, ds_orig.clat, ds_orig.temp.isel( time=0, height=60), cmap='coolwarm')
plt.title('Wind in 20m')
plt.xlabel('Longitude rad')  
plt.ylabel('Latitude rad')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

cbar = plt.colorbar() 
cbar.ax.set_ylabel('Velocity m/s')
# Out:
# Text(0, 0.5, 'Velocity m/s')

# %%
plt.figure(figsize=(9,7))
ax = plt.subplot(111)
plt.tripcolor(ds.clon, ds.clat, ds.w.isel( time=0, height_2=60), cmap='PiYG')
plt.title('Wind in 20m')
plt.xlabel('Longitude rad')  
plt.ylabel('Latitude rad')

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

cbar = plt.colorbar() 
cbar.ax.set_ylabel('Velocity m/s')
# Out:
# Text(0, 0.5, 'Velocity m/s')

# %%
sns.set_style("dark")

height = np.int(ds_run.z_ifc[60,0,0].values)
col_pal = sns.color_palette('PuOr')

temp = ds_run.temp.isel(time=0, height=60)

temp.plot.pcolormesh(cmap= 'coolwarm', cbar_kwargs={'label':'K'}, vmin=temp.mean()-2, vmax=temp.mean()+2)

plt.xlabel('Longitude (°)')
plt.ylabel('Latitude (°)')
plt.title('Semi-idealized temperature [%s m]' % height)
# Out:
# <img src="data:image/png;base64,..." width="660">
# Text(0.5, 1.0, 'Semi-idealized temperature [3910 m]')

# %%
temp.mean()
# Out:
# <xarray.DataArray 'temp' ()>
# array(279.4181, dtype=float32)
# Coordinates:
#     time     datetime64[ns] 2016-08-17T12:00:00
#     height   float64 61.0
